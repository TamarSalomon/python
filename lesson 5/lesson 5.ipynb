# %%
pip install pandas
# Out:
# ...
#
#   Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_19860\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# תרגיל 1

# %% [markdown]
# 1

# %%
data={'name': ['Lea','Dina'],'mark': [90,100],'class':['A','B']}
data
# Out:
# {'name': ['Lea', 'Dina'], 'mark': [90, 100], 'class': ['A', 'B']}

# %%
df = pd.DataFrame(data)
df
# Out:
#    name  mark class
# 0   Lea    90     A
# 1  Dina   100     B

# %% [markdown]
# 2

# %%
new_row = {'name': 'Kila', 'mark': 96, 'class': 'A'}
df.loc[len(df)] = new_row
df
# Out:
#    name  mark class
# 0   Lea    90     A
# 1  Dina   100     B
# 2  Kila    96     A

# %% [markdown]
# 3

# %%
df.name
# Out:
# 0     Lea
# 1    Dina
# 2    Kila
# Name: name, dtype: object

# %% [markdown]
# 4

# %%
df[df['class'] == 'A']
# Out:
#    name  mark class
# 0   Lea    90     A
# 2  Kila    96     A

# %% [markdown]
# 5

# %%
df.describe().max()
df[df['mark'] == 100]
# Out:
#    name  mark class
# 1  Dina   100     B

# %% [markdown]
# תרגיל 2

# %% [markdown]
# 1 - טעינת נתונים

# %%
df = pd.read_csv("Z:\B\סלומון תמר\pyton\pyton מתקדם\lesson 5\cities.csv")
df
# Out:
#      LatD   LatM   LatS    NS   LonD   LonM   LonS    EW                City  \
# 0      41      5   59.0   "N"     80     39    NaN   "W"        "Youngstown"
# 1      42     52   48.0   "N"     97     23   23.0   "W"           "Yankton"
# 2      46     35   59.0   "N"    120     30   36.0   "W"            "Yakima"
# 3      42     16   12.0   "N"     71     48    0.0   "W"         "Worcester"
# 4      43     37   48.0   "N"     89     46   11.0   "W"   "Wisconsin Dells"
# ..    ...    ...    ...   ...    ...    ...    ...   ...                 ...
# 123    39     31   12.0   "N"    119     48   35.0   "W"              "Reno"
# 124    50     25   11.0   "N"    104     39    0.0   "W"            "Regina"
# 125    40     10   48.0   "N"    122     14   23.0   "W"         "Red Bluff"
# 126    40     19   48.0   "N"     75     55   48.0   "W"           "Reading"
# 127    41      9   35.0   "N"     81     14   23.0   "W"           "Ravenna"
#
#      State
# 0       OH
# 1       SD
# ...

# %% [markdown]
# שלב 2: ניקוי נתונים

# %%
df.isnull().sum()
df.LatS = df.LatS.fillna(0)
df.LonS=  df.LonS.fillna(0)
df
# Out:
#      LatD  LatM  LatS    NS  LonD  LonM  LonS    EW                City State
# 0      41     5  59.0   "N"    80    39   0.0   "W"        "Youngstown"    OH
# 1      42    52  48.0   "N"    97    23  23.0   "W"           "Yankton"    SD
# 2      46    35  59.0   "N"   120    30  36.0   "W"            "Yakima"    WA
# 3      42    16  12.0   "N"    71    48   0.0   "W"         "Worcester"    MA
# 4      43    37  48.0   "N"    89    46  11.0   "W"   "Wisconsin Dells"    WI
# ..    ...   ...   ...   ...   ...   ...   ...   ...                 ...   ...
# 123    39    31  12.0   "N"   119    48  35.0   "W"              "Reno"    NV
# 124    50    25  11.0   "N"   104    39   0.0   "W"            "Regina"    SA
# 125    40    10  48.0   "N"   122    14  23.0   "W"         "Red Bluff"    CA
# 126    40    19  48.0   "N"    75    55  48.0   "W"           "Reading"    PA
# 127    41     9  35.0   "N"    81    14  23.0   "W"           "Ravenna"   OH
#
# [128 rows x 10 columns]

# %%
df.drop_duplicates()
# Out:
#      LatD  LatM  LatS    NS  LonD  LonM  LonS    EW                City State
# 0      41     5  59.0   "N"    80    39   0.0   "W"        "Youngstown"    OH
# 1      42    52  48.0   "N"    97    23  23.0   "W"           "Yankton"    SD
# 2      46    35  59.0   "N"   120    30  36.0   "W"            "Yakima"    WA
# 3      42    16  12.0   "N"    71    48   0.0   "W"         "Worcester"    MA
# 4      43    37  48.0   "N"    89    46  11.0   "W"   "Wisconsin Dells"    WI
# ..    ...   ...   ...   ...   ...   ...   ...   ...                 ...   ...
# 123    39    31  12.0   "N"   119    48  35.0   "W"              "Reno"    NV
# 124    50    25  11.0   "N"   104    39   0.0   "W"            "Regina"    SA
# 125    40    10  48.0   "N"   122    14  23.0   "W"         "Red Bluff"    CA
# 126    40    19  48.0   "N"    75    55  48.0   "W"           "Reading"    PA
# 127    41     9  35.0   "N"    81    14  23.0   "W"           "Ravenna"   OH
#
# [128 rows x 10 columns]

# %%
df.columns = df.columns.str.strip()  # מוריד רווחים

# %% [markdown]
# שלב 3: ניתוח וחישובים

# %%
df.LatD.mean()
# Out:
# 38.8203125

# %%
df.LatD.min()
# Out:
# 26

# %%
df.LatD.max()
# Out:
# 50

# %% [markdown]
# שלב 4: שינויים והוספות

# %%
df.insert(1 , 'newColumn' , df.LatD/df.LatM)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19860\4211981885.py in ?()
# ----> 1 df.insert(1 , 'newColumn' , df.LatD/df.LatM)
#       2 df
#
# C:\Python310\lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5141                 "'self.flags.allows_duplicate_labels' is False."
#    5142             )
#    5143         if not allow_duplicates and column in self.columns:
#    5144             # Should this be a different kind of error??
# -> 5145             raise ValueError(f"cannot insert {column}, already exists")
#    5146         if not is_integer(loc):
#    5147             raise TypeError("loc must be int")
#    5148         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert newColumn, already exists

# %%
df
# Out:
#      LatD  newColumn  LatM  LatS    NS  LonD  LonM  LonS    EW  \
# 0      41   8.200000     5  59.0   "N"    80    39   0.0   "W"
# 1      42   0.807692    52  48.0   "N"    97    23  23.0   "W"
# 2      46   1.314286    35  59.0   "N"   120    30  36.0   "W"
# 3      42   2.625000    16  12.0   "N"    71    48   0.0   "W"
# 4      43   1.162162    37  48.0   "N"    89    46  11.0   "W"
# ..    ...        ...   ...   ...   ...   ...   ...   ...   ...
# 123    39   1.258065    31  12.0   "N"   119    48  35.0   "W"
# 124    50   2.000000    25  11.0   "N"   104    39   0.0   "W"
# 125    40   4.000000    10  48.0   "N"   122    14  23.0   "W"
# 126    40   2.105263    19  48.0   "N"    75    55  48.0   "W"
# 127    41   4.555556     9  35.0   "N"    81    14  23.0   "W"
#
#                    City State
# 0          "Youngstown"    OH
# 1             "Yankton"    SD
# 2              "Yakima"    WA
# 3           "Worcester"    MA
# 4     "Wisconsin Dells"    WI
# ...

# %%
df.rename(columns={'newColumn': 'Population'}, inplace=True)
df
# Out:
#      LatD  Population  LatM  LatS    NS  LonD  LonM  LonS    EW  \
# 0      41    8.200000     5  59.0   "N"    80    39   0.0   "W"
# 1      42    0.807692    52  48.0   "N"    97    23  23.0   "W"
# 2      46    1.314286    35  59.0   "N"   120    30  36.0   "W"
# 3      42    2.625000    16  12.0   "N"    71    48   0.0   "W"
# 4      43    1.162162    37  48.0   "N"    89    46  11.0   "W"
# ..    ...         ...   ...   ...   ...   ...   ...   ...   ...
# 123    39    1.258065    31  12.0   "N"   119    48  35.0   "W"
# 124    50    2.000000    25  11.0   "N"   104    39   0.0   "W"
# 125    40    4.000000    10  48.0   "N"   122    14  23.0   "W"
# 126    40    2.105263    19  48.0   "N"    75    55  48.0   "W"
# 127    41    4.555556     9  35.0   "N"    81    14  23.0   "W"
#
#                    City State
# 0          "Youngstown"    OH
# 1             "Yankton"    SD
# 2              "Yakima"    WA
# 3           "Worcester"    MA
# 4     "Wisconsin Dells"    WI
# ...

# %% [markdown]
# שלב 5: סינון ומיון

# %%
df[df.LatD==41]
# Out:
#      LatD  Population  LatM  LatS    NS  LonD  LonM  LonS    EW  \
# 0      41    8.200000     5  59.0   "N"    80    39   0.0   "W"
# 11     41    2.733333    15   0.0   "N"    77     0   0.0   "W"
# 18     41    1.640000    25  11.0   "N"   122    23  23.0   "W"
# 25     41    1.281250    32  59.0   "N"    73     3   0.0   "W"
# 27     41    0.820000    50  59.0   "N"    79     8  23.0   "W"
# 49     41    1.051282    39   0.0   "N"    83    32  24.0   "W"
# 69     41    1.025000    40  48.0   "N"    86    15   0.0   "W"
# 79     41    1.708333    24  35.0   "N"    75    40  11.0   "W"
# 80     41    0.788462    52  11.0   "N"   103    39  36.0   "W"
# 91     41    1.518519    27   0.0   "N"    82    42  35.0   "W"
# 114    41    1.171429    35  24.0   "N"   109    13  48.0   "W"
# 127    41    4.555556     9  35.0   "N"    81    14  23.0   "W"
#
#                 City State
# 0       "Youngstown"    OH
# 11    "Williamsport"    PA
# 18            "Weed"    CA
# ...

# %%
df = df.sort_values('LatD',ascending=False)
df
# Out:
#      LatD  Population  LatM  LatS    NS  LonD  LonM  LonS    EW  \
# 124    50    2.000000    25  11.0   "N"   104    39   0.0   "W"
# 33     49    3.062500    16  12.0   "N"   123     7  12.0   "W"
# 6      49    0.942308    52   0.0   "N"    97     9   0.0   "W"
# 10     48    5.333333     9   0.0   "N"   103    37  12.0   "W"
# 68     47    1.175000    40  11.0   "N"   117    24  36.0   "W"
# ..    ...         ...   ...   ...   ...   ...   ...   ...   ...
# 108    29    0.547170    53  23.0   "N"    81    19  11.0   "W"
# 31     28    0.583333    48  35.0   "N"    97     0  36.0   "W"
# 52     27    0.473684    57   0.0   "N"    82    26  59.0   "W"
# 84     27    1.350000    20  24.0   "N"    82    31  47.0   "W"
# 16     26    0.604651    43  11.0   "N"    80     3   0.0   "W"
#
#                    City State
# 124            "Regina"    SA
# 33          "Vancouver"    BC
# 6            "Winnipeg"    MB
# 10          "Williston"    ND
# 68            "Spokane"    WA
# ...

# %% [markdown]
# שלב 6: יצוא נתונים

# %%
df.to_csv("Z:\B\סלומון תמר\pyton\pyton מתקדם\lesson 5\cities.csv").
